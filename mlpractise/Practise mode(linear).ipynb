# %%
#Linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("Book1.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  666000
# 2  3200  610000
# 3  3600  660000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.legend(df)
plt.scatter(df.area,df.price,color ='red',marker ='*')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([644321.91780822])

# %%
new_df = df.drop('price',axis='columns')

# %%
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
price = df.price
price
# Out:
# 0    550000
# 1    666000
# 2    610000
# 3    660000
# 4    725000
# Name: price, dtype: int64

# %%
reg = linear_model.LinearRegression()
reg.fit(new_df,df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[2200]]) # y = mx+b,x
# Out:
# array([527616.43835616])

# %%
reg.coef_  #input(m)
# Out:
# array([106.09589041])

# %%
reg.intercept_    #(b)
# Out:
# 294205.4794520548

# %%
#y=mx+b
2200*106.09589041+294205.4794520548
# Out:
# 527616.4383540547

# %%
reg.predict([[10000]])
# Out:
# array([1355164.38356164])

# %%
area_df = pd.read_csv("C:/Users/VK/Desktop/Book1.csv")
area_df.head(3)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  666000
# 2  3200  610000

# %%
x=area_df.drop('price',axis = 'columns')
x
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
p = reg.predict(x)
p
# Out:
# array([570054.79452055, 612493.15068493, 633712.32876712, 676150.68493151,
#        718589.04109589])

# %%
area_df['price']=p
area_df
# Out:
#    area          price
# 0  2600  570054.794521
# 1  3000  612493.150685
# 2  3200  633712.328767
# 3  3600  676150.684932
# 4  4000  718589.041096

# %%
area_df.to_csv("vkpredictprice.csv")

# %%
area_df
# Out:
#    area          price
# 0  2600  570054.794521
# 1  3000  612493.150685
# 2  3200  633712.328767
# 3  3600  676150.684932
# 4  4000  718589.041096

# %%
#Linear regression in multiple variant
# price = m1 * area + m2 * bedrooms + m3 * age + b
#area,bedrooms,age = features / m1,m2,m3 = cofficient / b = intercept(error)
#How to missing data set 
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df1 = pd.read_csv("Book2.csv")
df1
# Out:
#    area  bedroom  age   price
# 0  2500      3.0   20   55000
# 1  2900      NaN   12  565000
# 2  3400      4.0   18  610000
# 3  3600      3.0   30  595000
# 4  4000      5.0    8  760000

# %%
df1.bedroom.median()
# Out:
# 3.5

# %%
df1.bedroom = df1.bedroom.fillna(df1.bedroom.median())
df1.bedroom
# Out:
# 0    3.0
# 1    3.5
# 2    4.0
# 3    3.0
# 4    5.0
# Name: bedroom, dtype: float64

# %%
regression = linear_model.LinearRegression()
regression.fit(df1.drop('price',axis = 'columns'),df.price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([106.09589041])

# %%
reg.intercept_
# Out:
# 294205.4794520548

# %%
reg.predict([[3300]])    #Only linear regression
# Out:
# array([644321.91780822])

# %%
regression.predict([[2200,4,40]])   # Multiple linear regression
# Out:
# array([27062.36692081])

# %%
regression.coef_
# Out:
# array([    229.97939419, -169434.9886668 ,  -14103.9906587 ])

# %%
regression.intercept_
# Out:
# 763007.28071983

# %%
229.97939419* 2200-169434.9886668*4 -14103.9906587*40+763007.28071983
# Out:
# 27062.366922629997

# %%
import math
median_bedroom = math.floor(df1.bedroom.median())
median_bedroom
# Out:
# 3

# %%
regression.intercept_
# Out:
# 763007.28071983

# %%
regression.predict([[5000,4,40]])
# Out:
# array([671004.67065046])

# %%
# Python3 code to demonstrate working of 
# Convert numeric words to numbers 
# Using join() + split() 

help_dict = { 
	'one': '1', 
	'two': '2', 
	'three': '3', 
	'four': '4', 
	'five': '5', 
	'six': '6', 
	'seven': '7', 
	'eight': '8', 
	'nine': '9', 
	'zero' : '0'
} 

# initializing string 
test_str = "six seven nine zero zero nine five four one"

# printing original string 
print("The original string is : " + test_str) 

# Convert numeric words to numbers 
# Using join() + split() 
res = ''.join(help_dict[ele] for ele in test_str.split()) 

# printing result 
print("The string after performing replace : " + res)
# Out:
# The original string is : six seven nine zero zero nine five four one
# The string after performing replace : 679009541

# %%
# Python3 code to demonstrate working of 
# Convert numeric words to numbers 
# Using word2number 
from word2number import w2n 

# initializing string 
test_str = "zero fne zero"

# printing original string 
print("The original string is : " + test_str) 

# Convert numeric words to numbers 
# Using word2number 
res = w2n.word_to_num(test_str) 

# printing result 
print("The string after performing replace : " + str(res))
# Out:
# The original string is : zero One zero
# The string after performing replace : 0

# %%
# Gradiant loss
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 10000
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([5,7,8,9,4,5])
gradient_descent(x,y)
# Out:
# m 3.44, b 1.0133333333333332, cost 43.33333333333333 iteration 0
# m -2.0352, b -0.061866666666666736, cost 87.48195555555554 iteration 1
# m 6.378197333333334, b 2.1010773333333335, cost 195.3367079822222 iteration 2
# m -6.836164835555559, b -0.7935522133333341, cost 457.680580531845 iteration 3
# m 13.637317738192598, b 4.175001782044445, cost 1094.7298870579402 iteration 4
# m -18.353907637766333, b -3.116563103137188, cost 2640.669334481793 iteration 5
# m 31.370183567636793, b 8.673608603847242, cost 6391.28177726608 iteration 6
# m -46.172016041316276, b -9.26813823731159, cost 15489.771068017584 iteration 7
# m 74.50223363183903, b 19.084426197128717, cost 37560.66037607925 iteration 8
# m -113.53713198514907, b -24.676999494908404, cost 91098.88257816988 iteration 9
# m 179.2387613492947, b 43.865447669293744, cost 220967.90169469095 iteration 10
# m -276.838616886465, b -62.513396980064954, cost 535993.7604467785 iteration 11
# ...

# %%
plt.scatter(gradient_descent(x,y))
# Out:
# m 3.44, b 1.0133333333333332, cost 43.33333333333333 iteration 0
# m -2.0352, b -0.061866666666666736, cost 87.48195555555554 iteration 1
# m 6.378197333333334, b 2.1010773333333335, cost 195.3367079822222 iteration 2
# m -6.836164835555559, b -0.7935522133333341, cost 457.680580531845 iteration 3
# m 13.637317738192598, b 4.175001782044445, cost 1094.7298870579402 iteration 4
# m -18.353907637766333, b -3.116563103137188, cost 2640.669334481793 iteration 5
# m 31.370183567636793, b 8.673608603847242, cost 6391.28177726608 iteration 6
# m -46.172016041316276, b -9.26813823731159, cost 15489.771068017584 iteration 7
# m 74.50223363183903, b 19.084426197128717, cost 37560.66037607925 iteration 8
# m -113.53713198514907, b -24.676999494908404, cost 91098.88257816988 iteration 9
# m 179.2387613492947, b 43.865447669293744, cost 220967.90169469095 iteration 10
# m -276.838616886465, b -62.513396980064954, cost 535993.7604467785 iteration 11
# ...

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(regression,f)

# %%
with open('single_pickle','wb') as f:
    pickle.dump(reg,f)

# %%
with open('single_pickle','rb') as f:
    np = pickle.load(f)

# %%
with open('model_pickle','rb') as f:
    mp = pickle.load(f)

# %%
np.predict([[5000]])
# Out:
# array([824684.93150685])

# %%
mp.predict([[5000,5,40]])
# Out:
# array([501569.68198365])
